# %% [markdown]
# # **Introduction**

# %%
print("Hello World")

2 + 4
# Out:
# Hello World
# 6

# %% [markdown]
# # **What is Python?**

# %% [markdown]
# Welcome to the exciting world of Python programming. I'm glad you picked up this language and I sincerely hope this course can help you learn the Python language.

# %% [markdown]
# Python is a widely used high-level programming language created by Guido van Rossum in the late 1980s.

# %% [markdown]
# Like all high level programming languages, computers are unable to understand the Python. Therefore the Python codes have to be interpreted by a special program known as the Python interpreter, which we’ll need to install before we can code, test and execute our Python programs.

# %% [markdown]
# # **Why Learn Python?**

# %% [markdown]
# If you are new to programming, Python is a great place to start.

# %% [markdown]
# Python is very simple, making it the ideal language for beginners to learn.
#
# Most programs in Python require considerably fewer lines of code to perform the same task compared to other languages such as C.
#
# This leads to fewer programming errors and reduces the development time needed.

# %% [markdown]
# Python comes with an extensive collection of third party resources that extend the capabilities of the language.

# %% [markdown]
# As such, Python can be used for a large variety of tasks, such as for desktop applications, database applications, network programming, game programming and even mobile development.
#
#
# Last but not least, Python is a cross platform language, which means that code written for one operating system, such as Windows, will work well on Mac OS or Linux without making any changes to the Python code.

# %% [markdown]
# # **_Installing the Python Interpreter_**

# %% [markdown]
# To install the interpreter for Python 3, head over to the [Official Python Repository](https://www.python.org/downloads/). The correct version should be indicated at the top of the webpage. Click on the version for Python 3 and the software will start downloading.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# After the download is complete, cick to open the downloaded file.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Note**:
# * Remember to Select the checkbox for `Add Python 3.8 to PATH`
# * then click on `Install Now` to start the installation.

# %% [markdown]
# Click on **Close** when its done.
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# When installation is complete, type **IDLE** in your windows search box and open the Python's **"Integrated Development and Learning Environment"** App IDLE 3.8
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# IDLE opens up the Python shell for you.
#
# The Python Shell allows us to use Python in interactive mode.
#
# This means we can enter one command at a time. The Shell waits for a command from the user, executes it and returns the result of the execution.

# %% [markdown]
# # **Hello World: Our First Python Program**

# %% [markdown]
# To create a Python script, click on `File > New File` in the top menu of our Python Shell.
#
# This will bring up the text editor that we are going to use to write our very first program, the **“Hello World”** program.

# %% [markdown]
# Type the following code into the text editor (not the Shell).
#
# `# Prints the Words “Hello World”`
#
# `print("Hello World")`

# %% [markdown]
# Now click `File > Save As…` to save your code.
#
# Make sure you save it with the `.py` extension. Let's save the program as `ex01.py`

# %% [markdown]
# Finally click on `Run > Run Module` to execute the program (or press F5).
#
# You should see the words Hello World printed on your Python Shell.

# %% [markdown]
# # **Some very famous Python Toolkits**

# %% [markdown]
# ## [PyCharm](https://www.jetbrains.com/pycharm/)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# PyCharm is an integrated development environment (IDE) used for the Python language.
#
# * It is developed by the Czech company JetBrains.
# * It provides code analysis, a graphical debugger, an integrated unit tester, integration with version control systems (VCSes), and supports web development with Django as well as Data Science with Anaconda.

# %% [markdown]
# ## [Anaconda](https://www.anaconda.com/products/individual)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Anaconda provides various python development tools and packages e.g. spyder and jupyter which are the two most famous IDE for python development.
#
# * If you install Anaconda, you will have installed a lot of packages that are required for Machine Learning and Data Science Applications.

# %% [markdown]
# ## [Jupyter Notebook](https://jupyter.org/index.html)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **Jupyter notebook has several reasons to become popular.**
#
# * The **Jupyter Notebook** is an open-source web application that allows you to create and share documents that contain live code, equations, visualizations and narrative text.
# * Online platform which does not heat your computer.
# * You can code and run cell by cell.
# * Easy to Use.
# * No needed dedicated IDE of the python, it's run on your favorite browser.
# * Support over 100 programming languages like Python, Java, R, Julia, Matlab, Octave, Scheme, Processing, Scala, and many more.

# %% [markdown]
# ## [Google Colab](https://colab.research.google.com/)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * It's a Jupyter notebook environment that requires **no setup** to use and runs entirely in the cloud.
#
# * Colaboratory is a Google research project created to help disseminate machine learning education and research.
#
#
#
# * If you don't want to get into the trouble of installing all the required tools, interpreters, and packages on your local machine, then using Google colab is one of the safest option.

# %% [markdown]
# ## [repl.it](https://repl.it/)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# * Repl.it website is another way of making programs online without any hassle of installing compilers/interpreters on the local machine.
# * Create your account on repl and you can start making programs in many different languages such as C, C++, Java, JavaScript or Python.
# * The best things that you can even program on a mobile if you are using repl.it

# %% [markdown]
# ---

# %% [markdown]
# # **A quick guide to using Colab**

# %% [markdown]
# **Most useful keyboard Shortcut**
#
#
# | Keystroke      | Action                         |
# |----------------|--------------------------------|
# | `Ctrl + M + H` | Show keyboard shortcuts        |
# | `Ctrl + M + A` | Insert code cell above         |
# | `Ctrl + M + B` | Insert code cell below         |
# | `Ctrl + M + D` | Delete cell/selection          |
# | `Ctrl + M + Y` | Convert to code cell           |
# | `Ctrl + M + M` | Convert to text cell           |
# | `Ctrl + /`     | Comment/Uncomment the current code line|
# | `Ctrl + F9`    | Run all cells in notebook      |
# | `Alt + Enter`  | Run cell and insert new cell   |
# | `Shift + Enter`| Run cell and select next cell  |
# | `Ctrl + F8`    | Run cells before the current   |
# | `Ctrl + F10`   | Run selected cell and all cells after|
# | `Ctrl + Shift + Enter`| Run selection           |
# | `Ctrl + Enter` | Run the focused cell           |

# %% [markdown]
# You can view the full list of Colab shortcuts by using a keyboard shortcuts: `Ctrl + M + H`

# %% [markdown]
# ## Text cells
# This is a **text cell**. You can **double-click** to edit this cell. Text cells use markdown syntax.
#
# To learn more, see this [markdown guide](/notebooks/markdown_guide.ipynb).
#
# You can also add math to text cells using [LaTeX](http://www.latex-project.org/) to be rendered by [MathJax](https://www.mathjax.org). Just place the statement within a pair of **\$** signs. For example `$\sqrt{3x-1}+(1+x)^2$` becomes
# $\sqrt{3x-1}+(1+x)^2.$

# %% [markdown]
# ## Magics
#
# Colaboratory shares the notion of magics from Jupyter. There are shorthand annotations that change how a cell's text is executed.
#
# To learn more, see [Jupyter's magics page](http://nbviewer.jupyter.org/github/ipython/ipython/blob/1.x/examples/notebooks/Cell%20Magics.ipynb).

# %%
# %%html
# <marquee style='width: 30%; color: blue;'><b>Whee!</b></marquee>
# Out:
# <marquee style='width: 30%; color: blue;'><b>Whee!</b></marquee>

# %%
# %%html
# <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 450 400" width="200" height="200">
#   <rect x="80" y="60" width="250" height="250" rx="20" style="fill:red; stroke:black; fill-opacity:0.7" />
#   <rect x="180" y="110" width="250" height="250" rx="40" style="fill:blue; stroke:black; fill-opacity:0.5;" />
# </svg>
# Out:
# <svg xmlns="http://www.w3.org/2000/svg" viewBox="0 0 450 400" width="200" height="200">
#   <rect x="80" y="60" width="250" height="250" rx="20" style="fill:red; stroke:black; fill-opacity:0.7" />
#   <rect x="180" y="110" width="250" height="250" rx="40" style="fill:blue; stroke:black; fill-opacity:0.5;" />
# </svg>

# %% [markdown]
# # **Mounting Google Drive to colab**

# %% [markdown]
# All your colab codes are saved in the google drive folder `"Colab Notebooks"`. You can also use your Google Drive to store the data files and use it during programming.
#
# To do that you will need to mount the drive in colab session. You can mount google drive by following these steps:
#
# * Run the following code
# * When prompted, click the URL, then choose the Google account you wish to use.
# * Allow the `Google Drive File Stream` access to the selected google account
# * Then a `authorization code` will be displayed.
# * Copy the code and paste that in the space provided in the following cell

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %% [markdown]
# # **Revisiting Hello World: Our First Python Program**

# %% [markdown]
# ## Let's use Google Colab for learning Python

# %%
# Prints the Words “Hello World”
print("Hello World")

# Press Shift + Enter to execute any cell

#
# Out:
# Hello World

# %% [markdown]
# ## Comment in the Code
#
# Note, we have written the first line of code in the program as starting with a # symbol. This symbol tells the interpreter that the current line is a comment.
#
# Therefore,

# %%
# This is a comment
# This is also a comment
# This is yet another comment
# But this is not a comment
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# Alternatively, we can also use three single quotes (or three double quotes) for multiline comments, like this:

# %%
'''
This is a comment
This is also a comment
This is yet another comment
'''
print("Hello World")
# Out:
# Hello World
